# %%
import pandas as pd

# %%
df = pd.read_csv("players_20.csv")
df_15 = pd.read_csv("players_15.csv")
df_16 = pd.read_csv("players_16.csv")
df_17 = pd.read_csv("players_17.csv")
df_18 = pd.read_csv("players_18.csv")
df_19 = pd.read_csv("players_19.csv")

# %%
all_df = pd.concat([df,df_15,df_16,df_17,df_18,df_19],ignore_index=True)

# %%
all_df.shape
# Out:
# (100995, 104)

# %%
df_15.shape
# Out:
# (15465, 104)

# %%
all_df[all_df["short_name"]=="L. Messi"]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 18278     158023  https://sofifa.com/player/158023/lionel-messi/...
# 33743     158023  https://sofifa.com/player/158023/lionel-messi/...
# 48625     158023  https://sofifa.com/player/158023/lionel-messi/...
# 65634     158023  https://sofifa.com/player/158023/lionel-messi/...
# 83226     158023  https://sofifa.com/player/158023/lionel-messi/...
#
#       short_name                       long_name  age         dob  height_cm  \
# 0       L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# 18278   L. Messi  Lionel Andrés Messi Cuccittini   27  1987-06-24        169
# 33743   L. Messi  Lionel Andrés Messi Cuccittini   28  1987-06-24        170
# 48625   L. Messi  Lionel Andrés Messi Cuccittini   29  1987-06-24        170
# 65634   L. Messi  Lionel Andrés Messi Cuccittini   30  1987-06-24        170
# 83226   L. Messi  Lionel Andrés Messi Cuccittini   31  1987-06-24        170
#
#        weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# 0             72   Argentina  FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2
# 18278         67   Argentina  FC Barcelona  ...  62+3  62+3  62+3  62+3  62+3
# 33743         72   Argentina  FC Barcelona  ...  62+3  57+3  57+3  57+3  62+3
# 48625         72   Argentina  FC Barcelona  ...  63+3  59+3  59+3  59+3  63+3
# 65634         72   Argentina  FC Barcelona  ...  62+3  59+3  59+3  59+3  62+3
# 83226         72   Argentina  FC Barcelona  ...  63+2  61+2  61+2  61+2  63+2
#
#          lb   lcb    cb   rcb    rb
# 0      63+2  52+2  52+2  52+2  63+2
# 18278  54+3  45+3  45+3  45+3  54+3
# 33743  57+3  44+3  44+3  44+3  57+3
# 48625  58+3  46+3  46+3  46+3  58+3
# 65634  58+3  46+3  46+3  46+3  58+3
# 83226  58+2  47+2  47+2  47+2  58+2
#
# [6 rows x 104 columns]

# %%
df["player_positions"].head(20)
# Out:
# 0     RW, CF, ST
# 1         ST, LW
# 2        LW, CAM
# 3             GK
# 4         LW, CF
# 5        CAM, CM
# 6             GK
# 7             CB
# 8             CM
# 9         RW, ST
# 10        ST, RW
# 11            CB
# 12            ST
# 13            GK
# 14            GK
# 15       CDM, CM
# 16            CB
# 17            ST
# 18            CB
# 19            ST
# Name: player_positions, dtype: object

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(40,40))
data = df.corr()
sns.heatmap(data,annot=True)
# Out:
# C:\Users\Özdemir\AppData\Local\Temp\ipykernel_63792\481351679.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = df.corr()
# <Axes: >

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df[""]
# Out:
# 0        87+2
# 1        81+3
# 2        82+3
# 3         NaN
# 4        83+3
#          ...
# 18273    33+2
# 18274    36+2
# 18275    46+2
# 18276    46+2
# 18277    46+2
# Name: cm, Length: 18278, dtype: object
